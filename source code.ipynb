# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load your accident data (replace 'your_data.csv' with the actual file)
# Ensure the file path is correct and the file exists
file_path = 'your_data.csv'  # Update with your actual file path
try:
    accident_data = pd.read_csv(file_path)
except FileNotFoundError:
    print(f"Error: Accident data file not found at: {file_path}")
    # Instead of creating an empty DataFrame, providing a sample dataset:
    accident_data = pd.DataFrame({'Accident_Severity': [1, 2, 3, 2, 1]})
    # Replace with a relevant sample or raise FileNotFoundError if necessary.

print("First few rows of the data:")
print(accident_data.head())
print("\nData information:")
print(accident_data.info())
print("\nSummary statistics:")
print(accident_data.describe())
# Example: Analyze accident severity distribution
plt.figure(figsize=(8, 6))
# Check if the 'Accident_Severity' column exists in the DataFrame
if 'Accident_Severity' in accident_data.columns:
    sns.countplot(x='Accident_Severity', data=accident_data)
    plt.title('Distribution of Accident Severity')
    plt.xlabel('Severity Level')
    plt.ylabel('Number of Accidents')
    plt.show()
else:
    print("Warning: 'Accident_Severity' column not found in the data.")
# ... (rest of the code remains the same)
    plt.grid(True)
    plt.show()
# Example: Visualize accident hotspots using geographical coordinates
# Assuming you have 'Latitude' and 'Longitude' columns
if 'Latitude' in accident_data.columns and 'Longitude' in accident_data.columns:
    plt.figure(figsize=(10, 10))
    plt.scatter(accident_data['Longitude'], accident_data['Latitude'], s=10, alpha=0.5)
    plt.title('Accident Hotspots')
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')
    plt.grid(True)
    plt.show()
# Further analysis can involve correlations, relationships with weather, road conditions, etc.
# Out:
# Error: Accident data file not found at: your_data.csv
# First few rows of the data:
#    Accident_Severity
# 0                  1
# 1                  2
# 2                  3
# 3                  2
# 4                  1
#
# Data information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 1 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Accident_Severity  5 non-null      int64
# dtypes: int64(1)
# memory usage: 172.0 bytes
# None
#
# Summary statistics:
#        Accident_Severity
# count            5.00000
# mean             1.80000
# std              0.83666
# min              1.00000
# 25%              1.00000
# 50%              2.00000
# 75%              2.00000
# max              3.00000
